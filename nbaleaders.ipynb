# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data = pd.read_csv('data\\NBASeasonLeaders.csv')
nba = pd.DataFrame(data)

# %%
nba.describe()
# Out:
#              PPG        APG        RPG
# count  17.000000  17.000000  17.000000
# mean   28.194118   6.764706   6.500000
# std     3.049072   1.695561   3.021382
# min    24.800000   4.700000   2.800000
# 25%    26.300000   5.700000   4.200000
# 50%    27.500000   6.400000   5.400000
# 75%    28.300000   7.100000   8.500000
# max    35.300000  10.900000  12.200000

# %%
nba.head()
# Out:
#                    Players   PPG  APG   RPG
# 0               Joel Embid  35.3  5.7  11.3
# 1              Luka Doncic  34.3  9.6   9.6
# 2  Shai Gilgeous-Alexander  31.1  6.6   5.6
# 3    Giannis Antetokounmpo  30.8  6.3  11.4
# 4         Donavon Mitchell  28.3  6.3   5.4

# %%
nba.tail()
# Out:
#             Players   PPG  APG   RPG
# 12     Nikola Jokic  26.3  9.0  12.2
# 13  Anthony Edwards  25.8  5.3   5.2
# 14     Tyrese Maxey  25.6  6.4   3.6
# 15   Damian Lillard  24.8  6.8   4.2
# 16     LeBron James  24.8  7.8   7.3

# %%
nba.plot(kind="box")
plt.show()

# %%
nba.plot(kind="scatter", x="PPG", y="APG")
plt.show()

# %%
nba.items()
# Out:
# <generator object DataFrame.items at 0x0000017E15F81460>

# %%
nba._get_numeric_data()
# Out:
#      PPG   APG   RPG
# 0   35.3   5.7  11.3
# 1   34.3   9.6   9.6
# 2   31.1   6.6   5.6
# 3   30.8   6.3  11.4
# 4   28.3   6.3   5.4
# 5   28.3   5.7   6.5
# 6   28.0   7.1   4.7
# 7   28.0   4.9   4.4
# 8   27.5   6.5   3.9
# 9   27.0   4.7   8.5
# 10  27.0  10.9   2.8
# 11  26.4   5.4   3.9
# 12  26.3   9.0  12.2
# 13  25.8   5.3   5.2
# 14  25.6   6.4   3.6
# 15  24.8   6.8   4.2
# 16  24.8   7.8   7.3

# %%
plt.rc('xtick', labelsize=12)
plt.bar(x=nba.Players, height=nba.PPG, width=1, 
edgecolor="black", color="green")
#plt.figure().set_figwidth(100)
plt.rcParams['figure.figsize'] = [100, 10]
plt.show()

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Players  17 non-null     object
#  1   PPG      17 non-null     float64
#  2   APG      17 non-null     float64
#  3   RPG      17 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 672.0+ bytes

# %%
print(nba.axes);
# Out:
# [RangeIndex(start=0, stop=17, step=1), Index(['Players', 'PPG', 'APG', 'RPG'], dtype='object')]

# %%
print(nba.dtypes)
# Out:
# Players     object
# PPG        float64
# APG        float64
# RPG        float64
# dtype: object

# %%
print(nba.shape)
# Out:
# (17, 4)

# %%
print(nba.values)
# Out:
# [['Joel Embid' 35.3 5.7 11.3]
#  ['Luka Doncic' 34.3 9.6 9.6]
#  ['Shai Gilgeous-Alexander' 31.1 6.6 5.6]
#  ['Giannis Antetokounmpo' 30.8 6.3 11.4]
#  ['Donavon Mitchell' 28.3 6.3 5.4]
#  ['Kevin Durant' 28.3 5.7 6.5]
#  ['Devin Booker' 28.0 7.1 4.7]
#  ['Stephen Curry' 28.0 4.9 4.4]
#  ['Jalen Brunson' 27.5 6.5 3.9]
#  ['Jayson Tatum' 27.0 4.7 8.5]
#  ['Trae Young' 27.0 10.9 2.8]
#  ["De'Aaron Fox" 26.4 5.4 3.9]
#  ['Nikola Jokic' 26.3 9.0 12.2]
#  ['Anthony Edwards' 25.8 5.3 5.2]
#  ['Tyrese Maxey' 25.6 6.4 3.6]
#  ['Damian Lillard' 24.8 6.8 4.2]
#  ['LeBron James' 24.8 7.8 7.3]]
